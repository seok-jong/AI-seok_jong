# %% [markdown]
# # package import

# %%
import re    # 정규표현식 관련된 작업에 필요한 패키지
import os    # I/O 관련된 작업에 필요한 패키지 
import pandas as pd     # 데이터 전처리 관련된 작업에 필요한 패키지
import numpy as np      # 데이터 array 작업에 필요한 패키지
import tensorflow as tf  # 딥러닝 관련된 작업에 필요한 패키지
import matplotlib.pyplot as plt    # 데이터 시각화에 관련된 작업에 필요한 패키지
from sklearn.model_selection import train_test_split  # 데이터 전처리에 필요한 패키지

# %% [markdown]
# # 변수 생성

# %%
# 데이터 로드할 때 빠르게 로드할 수 있도록하는 설정 변수
AUTOTUNE = tf.data.experimental.AUTOTUNE

# 데이터 ROOT 경로 변수
ROOT_PATH = os.path.join(os.getenv('HOME'), 'aiffel')

# BATCH_SIZE 변수
BATCH_SIZE = 16

# X-RAY 이미지 사이즈 변수
IMAGE_SIZE = [180, 180]

# EPOCH 크기 변수
EPOCHS = 25

print(ROOT_PATH)
# Out:
# /home/ssac16/aiffel

# %% [markdown]
# # data load

# %%
train_filenames = tf.io.gfile.glob(str(ROOT_PATH + '/chest_xray/train/*/*'))
test_filenames = tf.io.gfile.glob(str(ROOT_PATH + '/chest_xray/test/*/*'))
val_filenames = tf.io.gfile.glob(str(ROOT_PATH + '/chest_xray/val/*/*'))

print(len(train_filenames))
print(len(test_filenames))
print(len(val_filenames))
# Out:
# 5216
# 624
# 16

# %% [markdown]
# # data ,val 데이터 수 조절

# %%
filenames = tf.io.gfile.glob(str(ROOT_PATH + '/chest_xray/train/*/*'))
filenames.extend(tf.io.gfile.glob(str(ROOT_PATH + '/chest_xray/val/*/*')))

# train, test(val) dataset으로 분할. test_size에 0.2는 20%롤 의미함.
train_filenames, val_filenames = train_test_split(filenames, test_size=0.2)

print(len(train_filenames))
print(len(val_filenames))
# Out:
# 4185
# 1047

# %%
COUNT_NORMAL = len([filename for filename in train_filenames if "NORMAL" in filename])
print("Normal images count in training set: " + str(COUNT_NORMAL))

COUNT_PNEUMONIA = len([filename for filename in train_filenames if "PNEUMONIA" in filename])
print("Pneumonia images count in training set: " + str(COUNT_PNEUMONIA))
# Out:
# Normal images count in training set: 1083
# Pneumonia images count in training set: 3102

# %% [markdown]
# # tf.data 인스턴스 생성

# %%
train_list_ds = tf.data.Dataset.from_tensor_slices(train_filenames)
val_list_ds = tf.data.Dataset.from_tensor_slices(val_filenames)

# %%
TRAIN_IMG_COUNT = tf.data.experimental.cardinality(train_list_ds).numpy()
print("Training images count: " + str(TRAIN_IMG_COUNT))

VAL_IMG_COUNT = tf.data.experimental.cardinality(val_list_ds).numpy()
print("Validating images count: " + str(VAL_IMG_COUNT))
# Out:
# Training images count: 4185
# Validating images count: 1047

# %% [markdown]
# # label 생성

# %%
CLASS_NAMES = np.array([str(tf.strings.split(item, os.path.sep)[-1].numpy())[2:-1]
                        for item in tf.io.gfile.glob(str(ROOT_PATH + "/chest_xray/train/*"))])
print(CLASS_NAMES)
# Out:
# ['PNEUMONIA' 'NORMAL']

# %%
def get_label(file_path):
    parts = tf.strings.split(file_path, os.path.sep)
    return parts[-2] == "PNEUMONIA"   # 폐렴이면 양성(True), 노말이면 음성(False)를 리턴하게 합니다.

# %% [markdown]
# # image size 변경 및 label 생성 함수

# %%
def decode_img(img):
  # 이미지를 uint8 tensor로 바꾼다.
  img = tf.image.decode_jpeg(img, channels=3)
  # img를 범위 [0,1]의 float32 데이터 타입으로 바꾼다.
  img = tf.image.convert_image_dtype(img, tf.float32)
  # img의 이미지 사이즈를 IMAGE_SIZE에서 지정한 사이즈로 수정한다.
  return tf.image.resize(img, IMAGE_SIZE)

def process_path(file_path):
    label = get_label(file_path)
    img = tf.io.read_file(file_path)
    img = decode_img(img)
    return img, label

train_ds = train_list_ds.map(process_path, num_parallel_calls=AUTOTUNE)
val_ds = val_list_ds.map(process_path, num_parallel_calls=AUTOTUNE)

for image, label in train_ds.take(1):
    print("Image shape: ", image.numpy().shape)
    print("Label: ", label.numpy())
# Out:
# Image shape:  (180, 180, 3)
# Label:  True

# %%
test_list_ds = tf.data.Dataset.list_files(str(ROOT_PATH + '/chest_xray/test/*/*'))
TEST_IMAGE_COUNT = tf.data.experimental.cardinality(test_list_ds).numpy()
test_ds = test_list_ds.map(process_path, num_parallel_calls=AUTOTUNE)
test_ds = test_ds.batch(BATCH_SIZE)

print(TEST_IMAGE_COUNT)
# Out:
# 624

# %% [markdown]
# # tf.data pipeline 생성

# %%
def prepare_for_training(ds, shuffle_buffer_size=1000):

    ds = ds.shuffle(buffer_size=shuffle_buffer_size)

    ds = ds.repeat()

    ds = ds.batch(BATCH_SIZE)

    ds = ds.prefetch(buffer_size=AUTOTUNE)

    return ds

train_ds = prepare_for_training(train_ds)
val_ds = prepare_for_training(val_ds)

# %%
def augment(image,label):
    image = tf.image.random_flip_left_right(image)  # 랜덤하게 좌우를 반전합니다.
    return image,label

def prepare_for_training(ds, shuffle_buffer_size=1000):
    # augment 적용 부분이 배치처리 함수에 추가되었습니다.
    ds = ds.map(
            augment,       # augment 함수 적용
            num_parallel_calls=2
        )

    ds = ds.shuffle(buffer_size=shuffle_buffer_size)

    ds = ds.repeat()

    ds = ds.batch(BATCH_SIZE)

    ds = ds.prefetch(buffer_size=AUTOTUNE)

    return ds

train_ds = prepare_for_training(train_ds)
val_ds = prepare_for_training(val_ds)

# %% [markdown]
# # 데이터 시각화

# %%
image_batch, label_batch = next(iter(train_ds))

def show_batch(image_batch, label_batch):
    plt.figure(figsize=(10,10))
    for n in range(16):
        ax = plt.subplot(5,5,n+1)
        plt.imshow(image_batch[n])
        if label_batch[n]:
            plt.title("PNEUMONIA")
        else:
            plt.title("NORMAL")
        plt.axis("off")

show_batch(image_batch.numpy(), label_batch.numpy())

# %% [markdown]
# # network 생성

# %%
def conv_block(filters):
    block = tf.keras.Sequential([
        tf.keras.layers.SeparableConv2D(filters, 3, activation='relu', padding='same'),
        tf.keras.layers.SeparableConv2D(filters, 3, activation='relu', padding='same'),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.MaxPool2D()
    ]
    )
    
    return block

def dense_block(units, dropout_rate):
    block = tf.keras.Sequential([
        tf.keras.layers.Dense(units, activation='relu'),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.Dropout(dropout_rate)
    ])
    
    return block

def build_model():
    model = tf.keras.Sequential([
        tf.keras.Input(shape=(IMAGE_SIZE[0], IMAGE_SIZE[1], 3)),
        
        tf.keras.layers.Conv2D(16, 3, activation='relu', padding='same'),
        tf.keras.layers.Conv2D(16, 3, activation='relu', padding='same'),
        tf.keras.layers.MaxPool2D(),
        
        conv_block(32),
        conv_block(64),
        
        conv_block(128),
        tf.keras.layers.Dropout(0.2),
        
        conv_block(256),
        tf.keras.layers.Dropout(0.2),
        
        tf.keras.layers.Flatten(),
        dense_block(512, 0.7),
        dense_block(128, 0.5),
        dense_block(64, 0.3),
        
        tf.keras.layers.Dense(1, activation='sigmoid')
    ])
    
    return model

# %% [markdown]
# # data imbalance 처리 - Weight balancing

# %%
weight_for_0 = (1 / COUNT_NORMAL)*(TRAIN_IMG_COUNT)/2.0 
weight_for_1 = (1 / COUNT_PNEUMONIA)*(TRAIN_IMG_COUNT)/2.0

class_weight = {0: weight_for_0, 1: weight_for_1}

print('Weight for class 0: {:.2f}'.format(weight_for_0))
print('Weight for class 1: {:.2f}'.format(weight_for_1))
# Out:
# Weight for class 0: 1.93
# Weight for class 1: 0.67

# %% [markdown]
# # train

# %%
with tf.device('/GPU:0'):
    model = build_model()

    METRICS = [
        'accuracy',
        tf.keras.metrics.Precision(name='precision'),
        tf.keras.metrics.Recall(name='recall')
    ]
    
    model.compile(
        optimizer='adam',
        loss='binary_crossentropy',
        metrics=METRICS
    )
    
with tf.device('/GPU:0'):
    history = model.fit(
        train_ds,
        steps_per_epoch=TRAIN_IMG_COUNT // BATCH_SIZE,
        epochs=EPOCHS,
        validation_data=val_ds,
        validation_steps=VAL_IMG_COUNT // BATCH_SIZE,
        class_weight=class_weight,
    )
# Out:
# Epoch 1/25
# 261/261 [==============================] - 24s 92ms/step - loss: 0.4312 - accuracy: 0.7886 - precision: 0.9431 - recall: 0.7606 - val_loss: 0.6761 - val_accuracy: 0.7442 - val_precision: 0.7442 - val_recall: 1.0000
# Epoch 2/25
# 261/261 [==============================] - 24s 92ms/step - loss: 0.2445 - accuracy: 0.9001 - precision: 0.9715 - recall: 0.8916 - val_loss: 1.0607 - val_accuracy: 0.7471 - val_precision: 0.7471 - val_recall: 1.0000
# Epoch 3/25
# 261/261 [==============================] - 24s 92ms/step - loss: 0.2070 - accuracy: 0.9279 - precision: 0.9748 - recall: 0.9266 - val_loss: 0.1717 - val_accuracy: 0.9240 - val_precision: 0.9122 - val_recall: 0.9935
# Epoch 4/25
# 261/261 [==============================] - 24s 92ms/step - loss: 0.2070 - accuracy: 0.9193 - precision: 0.9732 - recall: 0.9163 - val_loss: 0.1155 - val_accuracy: 0.9567 - val_precision: 0.9740 - val_recall: 0.9677
# Epoch 5/25
# 261/261 [==============================] - 24s 92ms/step - loss: 0.1801 - accuracy: 0.9325 - precision: 0.9776 - recall: 0.9302 - val_loss: 0.0966 - val_accuracy: 0.9683 - val_precision: 0.9685 - val_recall: 0.9897
# Epoch 6/25
# 261/261 [==============================] - 24s 91ms/step - loss: 0.1612 - accuracy: 0.9365 - precision: 0.9784 - recall: 0.9351 - val_loss: 0.0781 - val_accuracy: 0.9712 - val_precision: 0.9769 - val_recall: 0.9845
# Epoch 7/25
# 261/261 [==============================] - 23s 90ms/step - loss: 0.1712 - accuracy: 0.9370 - precision: 0.9790 - recall: 0.9350 - val_loss: 0.1228 - val_accuracy: 0.9567 - val_precision: 0.9585 - val_recall: 0.9845
# Epoch 8/25
# 261/261 [==============================] - 24s 90ms/step - loss: 0.1767 - accuracy: 0.9349 - precision: 0.9819 - recall: 0.9293 - val_loss: 0.1675 - val_accuracy: 0.9346 - val_precision: 0.9986 - val_recall: 0.9137
# Epoch 9/25
# 261/261 [==============================] - 24s 91ms/step - loss: 0.1638 - accuracy: 0.9397 - precision: 0.9811 - recall: 0.9368 - val_loss: 0.1343 - val_accuracy: 0.9423 - val_precision: 0.9343 - val_recall: 0.9922
# Epoch 10/25
# 261/261 [==============================] - 23s 89ms/step - loss: 0.1586 - accuracy: 0.9437 - precision: 0.9821 - recall: 0.9412 - val_loss: 0.1887 - val_accuracy: 0.9231 - val_precision: 0.9971 - val_recall: 0.8994
# Epoch 11/25
# 261/261 [==============================] - 23s 89ms/step - loss: 0.1587 - accuracy: 0.9416 - precision: 0.9833 - recall: 0.9368 - val_loss: 0.0840 - val_accuracy: 0.9750 - val_precision: 0.9796 - val_recall: 0.9871
# Epoch 12/25
# 261/261 [==============================] - 24s 91ms/step - loss: 0.1429 - accuracy: 0.9447 - precision: 0.9831 - recall: 0.9415 - val_loss: 0.1242 - val_accuracy: 0.9538 - val_precision: 0.9946 - val_recall: 0.9432
# Epoch 13/25
# 261/261 [==============================] - 24s 92ms/step - loss: 0.1383 - accuracy: 0.9468 - precision: 0.9836 - recall: 0.9442 - val_loss: 0.1223 - val_accuracy: 0.9529 - val_precision: 0.9427 - val_recall: 0.9974
# Epoch 14/25
# 261/261 [==============================] - 23s 90ms/step - loss: 0.1327 - accuracy: 0.9543 - precision: 0.9866 - recall: 0.9511 - val_loss: 0.0701 - val_accuracy: 0.9740 - val_precision: 0.9735 - val_recall: 0.9923
# Epoch 15/25
# 261/261 [==============================] - 23s 89ms/step - loss: 0.1100 - accuracy: 0.9583 - precision: 0.9889 - recall: 0.9544 - val_loss: 0.2031 - val_accuracy: 0.9192 - val_precision: 0.9986 - val_recall: 0.8932
# Epoch 16/25
# 261/261 [==============================] - 25s 95ms/step - loss: 0.1299 - accuracy: 0.9526 - precision: 0.9847 - recall: 0.9510 - val_loss: 0.0575 - val_accuracy: 0.9769 - val_precision: 0.9871 - val_recall: 0.9820
# Epoch 17/25
# 261/261 [==============================] - 25s 95ms/step - loss: 0.1203 - accuracy: 0.9528 - precision: 0.9868 - recall: 0.9488 - val_loss: 0.0942 - val_accuracy: 0.9625 - val_precision: 0.9960 - val_recall: 0.9535
# Epoch 18/25
# 261/261 [==============================] - 24s 90ms/step - loss: 0.1065 - accuracy: 0.9636 - precision: 0.9930 - recall: 0.9579 - val_loss: 0.3275 - val_accuracy: 0.8837 - val_precision: 0.9985 - val_recall: 0.8454
# Epoch 19/25
# 261/261 [==============================] - 24s 93ms/step - loss: 0.1245 - accuracy: 0.9523 - precision: 0.9868 - recall: 0.9482 - val_loss: 0.0887 - val_accuracy: 0.9673 - val_precision: 0.9856 - val_recall: 0.9703
# Epoch 20/25
# 261/261 [==============================] - 25s 95ms/step - loss: 0.1083 - accuracy: 0.9610 - precision: 0.9916 - recall: 0.9554 - val_loss: 0.0795 - val_accuracy: 0.9731 - val_precision: 0.9710 - val_recall: 0.9935
# Epoch 21/25
# 261/261 [==============================] - 23s 90ms/step - loss: 0.1005 - accuracy: 0.9636 - precision: 0.9904 - recall: 0.9604 - val_loss: 0.0638 - val_accuracy: 0.9760 - val_precision: 0.9908 - val_recall: 0.9768
# Epoch 22/25
# 261/261 [==============================] - 22s 85ms/step - loss: 0.1152 - accuracy: 0.9533 - precision: 0.9885 - recall: 0.9479 - val_loss: 0.0775 - val_accuracy: 0.9788 - val_precision: 0.9833 - val_recall: 0.9884
# Epoch 23/25
# 261/261 [==============================] - 23s 87ms/step - loss: 0.1114 - accuracy: 0.9598 - precision: 0.9893 - recall: 0.9560 - val_loss: 0.1812 - val_accuracy: 0.9385 - val_precision: 0.9267 - val_recall: 0.9961
# Epoch 24/25
# 261/261 [==============================] - 23s 87ms/step - loss: 0.0928 - accuracy: 0.9662 - precision: 0.9937 - recall: 0.9606 - val_loss: 0.0751 - val_accuracy: 0.9683 - val_precision: 0.9684 - val_recall: 0.9897
# Epoch 25/25
# 261/261 [==============================] - 23s 88ms/step - loss: 0.0922 - accuracy: 0.9701 - precision: 0.9924 - recall: 0.9670 - val_loss: 0.0639 - val_accuracy: 0.9731 - val_precision: 0.9908 - val_recall: 0.9729

# %% [markdown]
# # history 시각화

# %%
fig, ax = plt.subplots(1, 4, figsize=(20, 3))
ax = ax.ravel()

for i, met in enumerate(['precision', 'recall', 'accuracy', 'loss']):
    ax[i].plot(history.history[met])
    ax[i].plot(history.history['val_' + met])
    ax[i].set_title('Model {}'.format(met))
    ax[i].set_xlabel('epochs')
    ax[i].set_ylabel(met)
    ax[i].legend(['train', 'val'])

# %% [markdown]
# # test모델 평가

# %%
loss, acc, prec, rec = model.evaluate(test_ds)
# Out:
# 39/39 [==============================] - 2s 58ms/step - loss: 0.6272 - accuracy: 0.8349 - precision: 0.7996 - recall: 0.9821

# %% [markdown]
# augment를 적용하여 학습을 시킨 결과 기존의 정확도 였던 0.84보다 낮은 결과가 도출됨을 확인할 수 있었다. 따라서 위 코드를 하나로 합쳐 augment를 적용하지 않는 방식으로 epoch를 조정해본다.

# %% [markdown]
# # 통합 코드
# ## augment 적용하지 않음
# ## epoch 25 -> 22 로 조정

# %%
import re    # 정규표현식 관련된 작업에 필요한 패키지
import os    # I/O 관련된 작업에 필요한 패키지 
import pandas as pd     # 데이터 전처리 관련된 작업에 필요한 패키지
import numpy as np      # 데이터 array 작업에 필요한 패키지
import tensorflow as tf  # 딥러닝 관련된 작업에 필요한 패키지
import matplotlib.pyplot as plt    # 데이터 시각화에 관련된 작업에 필요한 패키지
from sklearn.model_selection import train_test_split  # 데이터 전처리에 필요한 패키지

# 데이터 로드할 때 빠르게 로드할 수 있도록하는 설정 변수
AUTOTUNE = tf.data.experimental.AUTOTUNE

# 데이터 ROOT 경로 변수
ROOT_PATH = os.path.join(os.getenv('HOME'), 'aiffel')

# BATCH_SIZE 변수
BATCH_SIZE = 16

# X-RAY 이미지 사이즈 변수
IMAGE_SIZE = [180, 180]

# EPOCH 크기 변수
EPOCHS = 26

print(ROOT_PATH)

train_filenames = tf.io.gfile.glob(str(ROOT_PATH + '/chest_xray/train/*/*'))
test_filenames = tf.io.gfile.glob(str(ROOT_PATH + '/chest_xray/test/*/*'))
val_filenames = tf.io.gfile.glob(str(ROOT_PATH + '/chest_xray/val/*/*'))

print(len(train_filenames))
print(len(test_filenames))
print(len(val_filenames))

filenames = tf.io.gfile.glob(str(ROOT_PATH + '/chest_xray/train/*/*'))
filenames.extend(tf.io.gfile.glob(str(ROOT_PATH + '/chest_xray/val/*/*')))

# train, test(val) dataset으로 분할. test_size에 0.2는 20%롤 의미함.
train_filenames, val_filenames = train_test_split(filenames, test_size=0.2)

print(len(train_filenames))
print(len(val_filenames))

COUNT_NORMAL = len([filename for filename in train_filenames if "NORMAL" in filename])
print("Normal images count in training set: " + str(COUNT_NORMAL))

COUNT_PNEUMONIA = len([filename for filename in train_filenames if "PNEUMONIA" in filename])
print("Pneumonia images count in training set: " + str(COUNT_PNEUMONIA))

train_list_ds = tf.data.Dataset.from_tensor_slices(train_filenames)
val_list_ds = tf.data.Dataset.from_tensor_slices(val_filenames)

TRAIN_IMG_COUNT = tf.data.experimental.cardinality(train_list_ds).numpy()
print("Training images count: " + str(TRAIN_IMG_COUNT))

VAL_IMG_COUNT = tf.data.experimental.cardinality(val_list_ds).numpy()
print("Validating images count: " + str(VAL_IMG_COUNT))

CLASS_NAMES = np.array([str(tf.strings.split(item, os.path.sep)[-1].numpy())[2:-1]
                        for item in tf.io.gfile.glob(str(ROOT_PATH + "/chest_xray/train/*"))])
print(CLASS_NAMES)

def get_label(file_path):
    parts = tf.strings.split(file_path, os.path.sep)
    return parts[-2] == "PNEUMONIA"   # 폐렴이면 양성(True), 노말이면 음성(False)를 리턴하게 합니다.

def decode_img(img):
  # 이미지를 uint8 tensor로 바꾼다.
  img = tf.image.decode_jpeg(img, channels=3)
  # img를 범위 [0,1]의 float32 데이터 타입으로 바꾼다.
  img = tf.image.convert_image_dtype(img, tf.float32)
  # img의 이미지 사이즈를 IMAGE_SIZE에서 지정한 사이즈로 수정한다.
  return tf.image.resize(img, IMAGE_SIZE)

def process_path(file_path):
    label = get_label(file_path)
    img = tf.io.read_file(file_path)
    img = decode_img(img)
    return img, label

train_ds = train_list_ds.map(process_path, num_parallel_calls=AUTOTUNE)
val_ds = val_list_ds.map(process_path, num_parallel_calls=AUTOTUNE)

for image, label in train_ds.take(1):
    print("Image shape: ", image.numpy().shape)
    print("Label: ", label.numpy())

test_list_ds = tf.data.Dataset.list_files(str(ROOT_PATH + '/chest_xray/test/*/*'))
TEST_IMAGE_COUNT = tf.data.experimental.cardinality(test_list_ds).numpy()
test_ds = test_list_ds.map(process_path, num_parallel_calls=AUTOTUNE)
test_ds = test_ds.batch(BATCH_SIZE)

print(TEST_IMAGE_COUNT)

def prepare_for_training(ds, shuffle_buffer_size=1000):

    ds = ds.shuffle(buffer_size=shuffle_buffer_size)

    ds = ds.repeat()

    ds = ds.batch(BATCH_SIZE)

    ds = ds.prefetch(buffer_size=AUTOTUNE)

    return ds

train_ds = prepare_for_training(train_ds)
val_ds = prepare_for_training(val_ds)

image_batch, label_batch = next(iter(train_ds))

def show_batch(image_batch, label_batch):
    plt.figure(figsize=(10,10))
    for n in range(16):
        ax = plt.subplot(5,5,n+1)
        plt.imshow(image_batch[n])
        if label_batch[n]:
            plt.title("PNEUMONIA")
        else:
            plt.title("NORMAL")
        plt.axis("off")

show_batch(image_batch.numpy(), label_batch.numpy())

def conv_block(filters):
    block = tf.keras.Sequential([
        tf.keras.layers.SeparableConv2D(filters, 3, activation='relu', padding='same'),
        tf.keras.layers.SeparableConv2D(filters, 3, activation='relu', padding='same'),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.MaxPool2D()
    ]
    )
    
    return block

def dense_block(units, dropout_rate):
    block = tf.keras.Sequential([
        tf.keras.layers.Dense(units, activation='relu'),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.Dropout(dropout_rate)
    ])
    
    return block

def build_model():
    model = tf.keras.Sequential([
        tf.keras.Input(shape=(IMAGE_SIZE[0], IMAGE_SIZE[1], 3)),
        
        tf.keras.layers.Conv2D(16, 3, activation='relu', padding='same'),
        tf.keras.layers.Conv2D(16, 3, activation='relu', padding='same'),
        tf.keras.layers.MaxPool2D(),
        
        conv_block(32),
        conv_block(64),
        
        conv_block(128),
        tf.keras.layers.Dropout(0.2),
        
        conv_block(256),
        tf.keras.layers.Dropout(0.2),
        
        tf.keras.layers.Flatten(),
        dense_block(512, 0.7),
        dense_block(128, 0.5),
        dense_block(64, 0.3),
        
        tf.keras.layers.Dense(1, activation='sigmoid')
    ])
    
    return model

weight_for_0 = (1 / COUNT_NORMAL)*(TRAIN_IMG_COUNT)/2.0 
weight_for_1 = (1 / COUNT_PNEUMONIA)*(TRAIN_IMG_COUNT)/2.0

class_weight = {0: weight_for_0, 1: weight_for_1}

print('Weight for class 0: {:.2f}'.format(weight_for_0))
print('Weight for class 1: {:.2f}'.format(weight_for_1))

with tf.device('/GPU:0'):
    model = build_model()

    METRICS = [
        'accuracy',
        tf.keras.metrics.Precision(name='precision'),
        tf.keras.metrics.Recall(name='recall')
    ]
    
    model.compile(
        optimizer='adam',
        loss='binary_crossentropy',
        metrics=METRICS
    )
    
with tf.device('/GPU:0'):
    history = model.fit(
        train_ds,
        steps_per_epoch=TRAIN_IMG_COUNT // BATCH_SIZE,
        epochs=EPOCHS,
        validation_data=val_ds,
        validation_steps=VAL_IMG_COUNT // BATCH_SIZE,
        class_weight=class_weight,
    )

fig, ax = plt.subplots(1, 4, figsize=(20, 3))
ax = ax.ravel()

for i, met in enumerate(['precision', 'recall', 'accuracy', 'loss']):
    ax[i].plot(history.history[met])
    ax[i].plot(history.history['val_' + met])
    ax[i].set_title('Model {}'.format(met))
    ax[i].set_xlabel('epochs')
    ax[i].set_ylabel(met)
    ax[i].legend(['train', 'val'])
# Out:
# /home/ssac16/aiffel
# 5216
# 624
# 16
# 4185
# 1047
# Normal images count in training set: 1077
# Pneumonia images count in training set: 3108
# Training images count: 4185
# Validating images count: 1047
# ['PNEUMONIA' 'NORMAL']
# Image shape:  (180, 180, 3)
# Label:  True
# 624
# Weight for class 0: 1.94
# Weight for class 1: 0.67
# Epoch 1/26
# 261/261 [==============================] - 23s 90ms/step - loss: 0.3885 - accuracy: 0.8202 - precision: 0.9568 - recall: 0.7936 - val_loss: 0.6436 - val_accuracy: 0.7423 - val_precision: 0.7423 - val_recall: 1.0000
# Epoch 2/26
# 261/261 [==============================] - 23s 89ms/step - loss: 0.2234 - accuracy: 0.9109 - precision: 0.9769 - recall: 0.9013 - val_loss: 1.1445 - val_accuracy: 0.7413 - val_precision: 0.7413 - val_recall: 1.0000
# Epoch 3/26
# 261/261 [==============================] - 23s 86ms/step - loss: 0.1833 - accuracy: 0.9349 - precision: 0.9800 - recall: 0.9314 - val_loss: 0.9072 - val_accuracy: 0.7433 - val_precision: 0.7425 - val_recall: 1.0000
# Epoch 4/26
# 261/261 [==============================] - 23s 87ms/step - loss: 0.2069 - accuracy: 0.9229 - precision: 0.9727 - recall: 0.9219 - val_loss: 0.2012 - val_accuracy: 0.9212 - val_precision: 0.9887 - val_recall: 0.9040
# Epoch 5/26
# 261/261 [==============================] - 23s 88ms/step - loss: 0.1427 - accuracy: 0.9444 - precision: 0.9831 - recall: 0.9412 - val_loss: 0.1025 - val_accuracy: 0.9635 - val_precision: 0.9717 - val_recall: 0.9792
# Epoch 6/26
# 261/261 [==============================] - 23s 88ms/step - loss: 0.1369 - accuracy: 0.9507 - precision: 0.9850 - recall: 0.9482 - val_loss: 0.1189 - val_accuracy: 0.9644 - val_precision: 0.9906 - val_recall: 0.9610
# Epoch 7/26
# 261/261 [==============================] - 23s 89ms/step - loss: 0.1415 - accuracy: 0.9432 - precision: 0.9841 - recall: 0.9387 - val_loss: 0.0867 - val_accuracy: 0.9663 - val_precision: 0.9804 - val_recall: 0.9740
# Epoch 8/26
# 261/261 [==============================] - 23s 90ms/step - loss: 0.1259 - accuracy: 0.9552 - precision: 0.9847 - recall: 0.9546 - val_loss: 0.2868 - val_accuracy: 0.9010 - val_precision: 0.9985 - val_recall: 0.8675
# Epoch 9/26
# 261/261 [==============================] - 24s 91ms/step - loss: 0.1259 - accuracy: 0.9552 - precision: 0.9866 - recall: 0.9526 - val_loss: 0.1868 - val_accuracy: 0.9260 - val_precision: 0.9131 - val_recall: 0.9948
# Epoch 10/26
# 261/261 [==============================] - 23s 88ms/step - loss: 0.1611 - accuracy: 0.9432 - precision: 0.9831 - recall: 0.9396 - val_loss: 0.4577 - val_accuracy: 0.8433 - val_precision: 0.9984 - val_recall: 0.7893
# Epoch 11/26
# 261/261 [==============================] - 24s 91ms/step - loss: 0.1333 - accuracy: 0.9500 - precision: 0.9876 - recall: 0.9447 - val_loss: 0.9906 - val_accuracy: 0.6663 - val_precision: 1.0000 - val_recall: 0.5482
# Epoch 12/26
# 261/261 [==============================] - 23s 88ms/step - loss: 0.1231 - accuracy: 0.9531 - precision: 0.9879 - recall: 0.9483 - val_loss: 0.2098 - val_accuracy: 0.9317 - val_precision: 0.9986 - val_recall: 0.9090
# Epoch 13/26
# 261/261 [==============================] - 23s 89ms/step - loss: 0.1056 - accuracy: 0.9605 - precision: 0.9881 - recall: 0.9585 - val_loss: 0.0990 - val_accuracy: 0.9635 - val_precision: 0.9854 - val_recall: 0.9649
# Epoch 14/26
# 261/261 [==============================] - 23s 89ms/step - loss: 0.1163 - accuracy: 0.9567 - precision: 0.9876 - recall: 0.9535 - val_loss: 0.3407 - val_accuracy: 0.8750 - val_precision: 0.8587 - val_recall: 0.9948
# Epoch 15/26
# 261/261 [==============================] - 23s 88ms/step - loss: 0.0864 - accuracy: 0.9708 - precision: 0.9940 - recall: 0.9664 - val_loss: 0.1185 - val_accuracy: 0.9606 - val_precision: 0.9585 - val_recall: 0.9896
# Epoch 16/26
# 261/261 [==============================] - 24s 91ms/step - loss: 0.0846 - accuracy: 0.9727 - precision: 0.9931 - recall: 0.9701 - val_loss: 0.0692 - val_accuracy: 0.9740 - val_precision: 0.9856 - val_recall: 0.9792
# Epoch 17/26
# 261/261 [==============================] - 23s 88ms/step - loss: 0.0899 - accuracy: 0.9660 - precision: 0.9917 - recall: 0.9625 - val_loss: 0.2047 - val_accuracy: 0.9221 - val_precision: 1.0000 - val_recall: 0.8948
# Epoch 18/26
# 261/261 [==============================] - 23s 90ms/step - loss: 0.0734 - accuracy: 0.9739 - precision: 0.9934 - recall: 0.9713 - val_loss: 0.0712 - val_accuracy: 0.9731 - val_precision: 0.9960 - val_recall: 0.9676
# Epoch 19/26
# 261/261 [==============================] - 23s 90ms/step - loss: 0.0799 - accuracy: 0.9705 - precision: 0.9927 - recall: 0.9674 - val_loss: 0.1004 - val_accuracy: 0.9635 - val_precision: 0.9973 - val_recall: 0.9532
# Epoch 20/26
# 261/261 [==============================] - 23s 89ms/step - loss: 0.0979 - accuracy: 0.9641 - precision: 0.9923 - recall: 0.9591 - val_loss: 0.1701 - val_accuracy: 0.9356 - val_precision: 0.9958 - val_recall: 0.9169
# Epoch 21/26
# 261/261 [==============================] - 24s 91ms/step - loss: 0.0862 - accuracy: 0.9677 - precision: 0.9910 - recall: 0.9651 - val_loss: 0.0783 - val_accuracy: 0.9721 - val_precision: 0.9920 - val_recall: 0.9702
# Epoch 22/26
# 261/261 [==============================] - 24s 92ms/step - loss: 0.0787 - accuracy: 0.9696 - precision: 0.9921 - recall: 0.9668 - val_loss: 0.1745 - val_accuracy: 0.9404 - val_precision: 0.9986 - val_recall: 0.9207
# Epoch 23/26
# 261/261 [==============================] - 24s 90ms/step - loss: 0.0840 - accuracy: 0.9696 - precision: 0.9921 - recall: 0.9668 - val_loss: 0.0864 - val_accuracy: 0.9615 - val_precision: 0.9906 - val_recall: 0.9572
# Epoch 24/26
# 261/261 [==============================] - 24s 91ms/step - loss: 0.0659 - accuracy: 0.9765 - precision: 0.9947 - recall: 0.9735 - val_loss: 0.1484 - val_accuracy: 0.9500 - val_precision: 0.9986 - val_recall: 0.9338
# Epoch 25/26
# 261/261 [==============================] - 24s 92ms/step - loss: 0.0897 - accuracy: 0.9701 - precision: 0.9914 - recall: 0.9681 - val_loss: 0.1176 - val_accuracy: 0.9500 - val_precision: 0.9945 - val_recall: 0.9377
# Epoch 26/26
# 261/261 [==============================] - 24s 91ms/step - loss: 0.0564 - accuracy: 0.9777 - precision: 0.9960 - recall: 0.9739 - val_loss: 0.1133 - val_accuracy: 0.9606 - val_precision: 0.9986 - val_recall: 0.9481

# %%
loss, acc, prec, rec = model.evaluate(test_ds)
# Out:
# 39/39 [==============================] - 2s 62ms/step - loss: 0.7353 - accuracy: 0.8590 - precision: 0.8240 - recall: 0.9846

# %% [markdown]
# batch size는 크게하면 학습 속도가 빨라지는 대신 정확도가 상대적으로 낮아지고 작게하면 학습속도가 조금더 오래걸리는 대신 정확도가 올라가게 된다. 따라서 높은 정확도를 내기 위해 batch size를 16으로 유지하였고
# epoch는 25일때, 84%였고 조금씩 줄여가며 학습을 시켰을 때 더 낮은 정확도가 나왔다. epoch를 30으로 했을 경우도 낮은 정확도가 나왔다.
# history를 통해 학습의 경향을 살펴 보았을 때, 24epoch정도에서 정확도가 점점 상승하는 경향을 보였기에 epoch를 26으로 조정하고 학습을 시킨결과 정확도가 **85.9%**가 나온것을 확인할 수 있다.
