# %% [markdown]
# # Spectrogram 생성

# %%
import numpy as np
import os
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow.keras import layers
import matplotlib.pyplot as plt
import librosa
import librosa.display

#data load 
data_path = os.getenv("HOME")+'/aiffel/speech_recognition/data/speech_wav_8000.npz'
speech_data = np.load(data_path)


#make label table 
target_list = ['yes', 'no', 'up', 'down', 'left', 'right', 'on', 'off', 'stop', 'go']

label_value = target_list
label_value.append('unknown')
label_value.append('silence')

print('LABEL : ', label_value)

new_label_value = dict()
for i, l in enumerate(label_value):
    new_label_value[l] = i
label_value = new_label_value

print('Indexed LABEL : ', new_label_value)



#indexing label
temp = []
for v in speech_data["label_vals"]:
    temp.append(label_value[v[0]])
label_data = np.array(temp)



def wav2spec(wav, fft_size=258): # spectrogram shape을 맞추기위해서 size 변형
    D = np.abs(librosa.stft(wav, n_fft=fft_size))
    return D

data=speech_data["wav_vals"][200]


spec = wav2spec(data)
print("Waveform shape : ",data.shape)
print("Spectrogram shape : ",spec.shape)


librosa.display.specshow(librosa.amplitude_to_db(spec, ref=np.max), x_axis='time')
plt.title('Power spectrogram')
plt.colorbar(format='%+2.0f dB')
plt.xticks(range(0, 1))
plt.tight_layout()
plt.show()
# Out:
# LABEL :  ['yes', 'no', 'up', 'down', 'left', 'right', 'on', 'off', 'stop', 'go', 'unknown', 'silence']
# Indexed LABEL :  {'yes': 0, 'no': 1, 'up': 2, 'down': 3, 'left': 4, 'right': 5, 'on': 6, 'off': 7, 'stop': 8, 'go': 9, 'unknown': 10, 'silence': 11}
# Waveform shape :  (8000,)
# Spectrogram shape :  (130, 126)

# %% [markdown]
# # spectrogram - norm모델

# %%
import numpy as np
import os
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow.keras import layers
import matplotlib.pyplot as plt
import librosa
import librosa.display

#data load 
data_path = os.getenv("HOME")+'/aiffel/speech_recognition/data/speech_wav_8000.npz'
speech_data = np.load(data_path)


#make label table 
target_list = ['yes', 'no', 'up', 'down', 'left', 'right', 'on', 'off', 'stop', 'go']

label_value = target_list
label_value.append('unknown')
label_value.append('silence')

print('LABEL : ', label_value)

new_label_value = dict()
for i, l in enumerate(label_value):
    new_label_value[l] = i
label_value = new_label_value

print('Indexed LABEL : ', new_label_value)



#indexing label
temp = []
for v in speech_data["label_vals"]:
    temp.append(label_value[v[0]])
label_data = np.array(temp)



def wav2spec(wav, fft_size=258): # spectrogram shape을 맞추기위해서 size 변형
    D = np.abs(librosa.stft(wav, n_fft=fft_size))
    return D





tmp=[]
for i in speech_data["wav_vals"]:
    tmp.append(wav2spec(i))
    
spec_data=np.array(tmp)
    






'''
print(data.shape)
print(data)
spec = wav2spec(data)
print("Waveform shape : ",data.shape)
print("Spectrogram shape : ",spec.shape)


librosa.display.specshow(librosa.amplitude_to_db(spec, ref=np.max), x_axis='time')
plt.title('Power spectrogram')
plt.colorbar(format='%+2.0f dB')
plt.xticks(range(0, 1))
plt.tight_layout()
plt.show()

'''

#split
sr = 130
sc=126
train_wav, test_wav, train_label, test_label = train_test_split(spec_data, 
                                                                label_data, 
                                                                test_size=0.1,
                                                                shuffle=True)











train_wav = train_wav.reshape([-1, sr,sc, 1]) # add channel for CNN
test_wav = test_wav.reshape([-1, sr,sc, 1])

print("asdasdasd ",train_wav.shape)


print("train data : ", train_wav.shape)
print("train labels : ", train_label.shape)
print("test data : ", test_wav.shape)
print("test labels : ", test_label.shape)

del speech_data
del spec_data


#hyper parameters setting
batch_size = 32
max_epochs = 10

# the save point
checkpoint_dir = os.getenv('HOME')+'/aiffel/speech_recognition/models/spectrogram_norm'

checkpoint_dir



# make dataset
def one_hot_label(wav, label):
    label = tf.one_hot(label, depth=12)
    return wav, label
# for train
train_dataset = tf.data.Dataset.from_tensor_slices((train_wav, train_label))
train_dataset = train_dataset.map(one_hot_label)
train_dataset = train_dataset.repeat().batch(batch_size=batch_size)
print(train_dataset)

# for test
test_dataset = tf.data.Dataset.from_tensor_slices((test_wav, test_label))
test_dataset = test_dataset.map(one_hot_label)
test_dataset = test_dataset.batch(batch_size=batch_size)
print(test_dataset)




#network 
input_tensor = layers.Input(shape=(sr,sc, 1))

x = layers.Conv2D(32, 9, padding='same', activation='relu')(input_tensor)
x = layers.Conv2D(32, 9, padding='same', activation='relu')(x)
x = layers.MaxPool2D()(x)

x = layers.Conv2D(64, 9, padding='same', activation='relu')(x)
x = layers.Conv2D(64, 9, padding='same', activation='relu')(x)
x = layers.MaxPool2D()(x)

x = layers.Conv2D(128, 9, padding='same', activation='relu')(x)
x = layers.Conv2D(128, 9, padding='same', activation='relu')(x)
x = layers.Conv2D(128, 9, padding='same', activation='relu')(x)
x = layers.MaxPool2D()(x)

x = layers.Conv2D(256, 9, padding='same', activation='relu')(x)
x = layers.Conv2D(256, 9, padding='same', activation='relu')(x)
x = layers.Conv2D(256, 9, padding='same', activation='relu')(x)
x = layers.MaxPool2D()(x)
x = layers.Dropout(0.3)(x)

x = layers.Flatten()(x)
x = layers.Dense(256)(x)
x = layers.BatchNormalization()(x)
x = layers.Activation('relu')(x)

output_tensor = layers.Dense(12)(x)

model_wav = tf.keras.Model(input_tensor, output_tensor)

model_wav.summary()


optimizer=tf.keras.optimizers.Adam(1e-4)
model_wav.compile(loss=tf.keras.losses.CategoricalCrossentropy(from_logits=True),
             optimizer=optimizer,
             metrics=['accuracy'])

#callback 
cp_callback = tf.keras.callbacks.ModelCheckpoint(checkpoint_dir,
                                                 save_weights_only=True,
                                                 monitor='val_loss',
                                                 mode='auto',
                                                 save_best_only=True,
                                                 verbose=1)




#30분 내외 소요 (메모리 사용량에 주의해 주세요.)
history_wav = model_wav.fit(train_dataset, epochs=max_epochs,
                    steps_per_epoch=len(train_wav) // batch_size,
                    validation_data=test_dataset,
                    validation_steps=len(test_wav) // batch_size,
                    callbacks=[cp_callback]
                    )



acc = history_wav.history['accuracy']
val_acc = history_wav.history['val_accuracy']

loss=history_wav.history['loss']
val_loss=history_wav.history['val_loss']

epochs_range = range(len(acc))

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()



#evaluation
model_wav.load_weights(checkpoint_dir)
results = model_wav.evaluate(test_dataset)
# loss
print("loss value: {:.3f}".format(results[0]))
# accuracy
print("accuracy value: {:.4f}%".format(results[1]*100))
# Out:
# LABEL :  ['yes', 'no', 'up', 'down', 'left', 'right', 'on', 'off', 'stop', 'go', 'unknown', 'silence']
# Indexed LABEL :  {'yes': 0, 'no': 1, 'up': 2, 'down': 3, 'left': 4, 'right': 5, 'on': 6, 'off': 7, 'stop': 8, 'go': 9, 'unknown': 10, 'silence': 11}
# asdasdasd  (45558, 130, 126, 1)
# train data :  (45558, 130, 126, 1)
# train labels :  (45558,)
# test data :  (5062, 130, 126, 1)
# test labels :  (5062,)
# <BatchDataset shapes: ((None, 130, 126, 1), (None, 12)), types: (tf.float32, tf.float32)>
# <BatchDataset shapes: ((None, 130, 126, 1), (None, 12)), types: (tf.float32, tf.float32)>
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 130, 126, 1)]     0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 130, 126, 32)      2624
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 130, 126, 32)      82976
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 65, 63, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 65, 63, 64)        165952
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 65, 63, 64)        331840
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 32, 31, 64)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 32, 31, 128)       663680
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 32, 31, 128)       1327232
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 32, 31, 128)       1327232
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 16, 15, 128)       0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 16, 15, 256)       2654464
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 16, 15, 256)       5308672
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 16, 15, 256)       5308672
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 8, 7, 256)         0
# _________________________________________________________________
# dropout (Dropout)            (None, 8, 7, 256)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 14336)             0
# _________________________________________________________________
# dense (Dense)                (None, 256)               3670272
# _________________________________________________________________
# batch_normalization (BatchNo (None, 256)               1024
# _________________________________________________________________
# activation (Activation)      (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 12)                3084
# =================================================================
# Total params: 20,847,724
# Trainable params: 20,847,212
# Non-trainable params: 512
# _________________________________________________________________
# Epoch 1/10
# 1423/1423 [==============================] - ETA: 0s - loss: 0.7294 - accuracy: 0.7558
# Epoch 00001: val_loss improved from inf to 0.42050, saving model to /home/ssac16/aiffel/speech_recognition/models/spectrogram_norm
# 1423/1423 [==============================] - 202s 142ms/step - loss: 0.7294 - accuracy: 0.7558 - val_loss: 0.4205 - val_accuracy: 0.8748
# Epoch 2/10
# 1423/1423 [==============================] - ETA: 0s - loss: 0.2443 - accuracy: 0.9235
# Epoch 00002: val_loss improved from 0.42050 to 0.22939, saving model to /home/ssac16/aiffel/speech_recognition/models/spectrogram_norm
# 1423/1423 [==============================] - 200s 141ms/step - loss: 0.2443 - accuracy: 0.9235 - val_loss: 0.2294 - val_accuracy: 0.9231
# Epoch 3/10
# 1423/1423 [==============================] - ETA: 0s - loss: 0.1705 - accuracy: 0.9456
# Epoch 00003: val_loss improved from 0.22939 to 0.16070, saving model to /home/ssac16/aiffel/speech_recognition/models/spectrogram_norm
# 1423/1423 [==============================] - 200s 140ms/step - loss: 0.1705 - accuracy: 0.9456 - val_loss: 0.1607 - val_accuracy: 0.9508
# Epoch 4/10
# 1423/1423 [==============================] - ETA: 0s - loss: 0.1327 - accuracy: 0.9571
# Epoch 00004: val_loss did not improve from 0.16070
# 1423/1423 [==============================] - 200s 141ms/step - loss: 0.1327 - accuracy: 0.9571 - val_loss: 0.1786 - val_accuracy: 0.9436
# Epoch 5/10
# 1423/1423 [==============================] - ETA: 0s - loss: 0.1081 - accuracy: 0.9643
# Epoch 00005: val_loss improved from 0.16070 to 0.12201, saving model to /home/ssac16/aiffel/speech_recognition/models/spectrogram_norm
# 1423/1423 [==============================] - 198s 139ms/step - loss: 0.1081 - accuracy: 0.9643 - val_loss: 0.1220 - val_accuracy: 0.9608
# Epoch 6/10
# 1423/1423 [==============================] - ETA: 0s - loss: 0.0931 - accuracy: 0.9694
# Epoch 00006: val_loss improved from 0.12201 to 0.11297, saving model to /home/ssac16/aiffel/speech_recognition/models/spectrogram_norm
# 1423/1423 [==============================] - 199s 140ms/step - loss: 0.0931 - accuracy: 0.9694 - val_loss: 0.1130 - val_accuracy: 0.9640
# Epoch 7/10
# 1423/1423 [==============================] - ETA: 0s - loss: 0.0836 - accuracy: 0.9720
# Epoch 00007: val_loss did not improve from 0.11297
# 1423/1423 [==============================] - 198s 139ms/step - loss: 0.0836 - accuracy: 0.9720 - val_loss: 0.1247 - val_accuracy: 0.9624
# Epoch 8/10
# 1423/1423 [==============================] - ETA: 0s - loss: 0.0779 - accuracy: 0.9736
# Epoch 00008: val_loss improved from 0.11297 to 0.10908, saving model to /home/ssac16/aiffel/speech_recognition/models/spectrogram_norm
# 1423/1423 [==============================] - 199s 140ms/step - loss: 0.0779 - accuracy: 0.9736 - val_loss: 0.1091 - val_accuracy: 0.9654
# Epoch 9/10
# 1423/1423 [==============================] - ETA: 0s - loss: 0.0694 - accuracy: 0.9766
# Epoch 00009: val_loss improved from 0.10908 to 0.10521, saving model to /home/ssac16/aiffel/speech_recognition/models/spectrogram_norm
# 1423/1423 [==============================] - 202s 142ms/step - loss: 0.0694 - accuracy: 0.9766 - val_loss: 0.1052 - val_accuracy: 0.9654
# Epoch 10/10
# 1423/1423 [==============================] - ETA: 0s - loss: 0.0641 - accuracy: 0.9781
# Epoch 00010: val_loss did not improve from 0.10521
# 1423/1423 [==============================] - 201s 141ms/step - loss: 0.0641 - accuracy: 0.9781 - val_loss: 0.1374 - val_accuracy: 0.9598
# 159/159 [==============================] - 26s 163ms/step - loss: 0.1051 - accuracy: 0.9654
# loss value: 0.105
# accuracy value: 96.5429%

# %% [markdown]
# # spectrogram - skip모델

# %%
import numpy as np
import os
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow.keras import layers
import matplotlib.pyplot as plt
import librosa
import librosa.display


data_path = os.getenv("HOME")+'/aiffel/speech_recognition/data/speech_wav_8000.npz'
speech_data = np.load(data_path)


#make label table 
target_list = ['yes', 'no', 'up', 'down', 'left', 'right', 'on', 'off', 'stop', 'go']

label_value = target_list
label_value.append('unknown')
label_value.append('silence')

print('LABEL : ', label_value)

new_label_value = dict()
for i, l in enumerate(label_value):
    new_label_value[l] = i
label_value = new_label_value

print('Indexed LABEL : ', new_label_value)



#indexing label
temp = []
for v in speech_data["label_vals"]:
    temp.append(label_value[v[0]])
label_data = np.array(temp)



def wav2spec(wav, fft_size=258): # spectrogram shape을 맞추기위해서 size 변형
    D = np.abs(librosa.stft(wav, n_fft=fft_size))
    return D





tmp=[]
for i in speech_data["wav_vals"]:
    tmp.append(wav2spec(i))
    
spec_data=np.array(tmp)
    






'''
print(data.shape)
print(data)
spec = wav2spec(data)
print("Waveform shape : ",data.shape)
print("Spectrogram shape : ",spec.shape)


librosa.display.specshow(librosa.amplitude_to_db(spec, ref=np.max), x_axis='time')
plt.title('Power spectrogram')
plt.colorbar(format='%+2.0f dB')
plt.xticks(range(0, 1))
plt.tight_layout()
plt.show()
'''


#split
sr = 130
sc=126
train_wav, test_wav, train_label, test_label = train_test_split(spec_data, 
                                                                label_data, 
                                                                test_size=0.1,
                                                                shuffle=True)











train_wav = train_wav.reshape([-1, sr,sc, 1]) # add channel for CNN
test_wav = test_wav.reshape([-1, sr,sc, 1])

print("asdasdasd ",train_wav.shape)


print("train data : ", train_wav.shape)
print("train labels : ", train_label.shape)
print("test data : ", test_wav.shape)
print("test labels : ", test_label.shape)

del speech_data
del spec_data


#hyper parameters setting
batch_size = 16
max_epochs = 10

# the save point
checkpoint_dir = os.getenv('HOME')+'/aiffel/speech_recognition/models/spectrogram_skip'

checkpoint_dir



# make dataset
def one_hot_label(wav, label):
    label = tf.one_hot(label, depth=12)
    return wav, label
# for train
train_dataset = tf.data.Dataset.from_tensor_slices((train_wav, train_label))
train_dataset = train_dataset.map(one_hot_label)
train_dataset = train_dataset.repeat().batch(batch_size=batch_size)
print(train_dataset)

# for test
test_dataset = tf.data.Dataset.from_tensor_slices((test_wav, test_label))
test_dataset = test_dataset.map(one_hot_label)
test_dataset = test_dataset.batch(batch_size=batch_size)
print(test_dataset)




#network 
input_tensor = layers.Input(shape=(sr,sc, 1))

x = layers.Conv2D(32, 9, padding='same', activation='relu')(input_tensor)
x = layers.Conv2D(32, 9, padding='same', activation='relu')(x)
skip_1 = layers.MaxPool2D()(x)

x = layers.Conv2D(64, 9, padding='same', activation='relu')(skip_1)
x = layers.Conv2D(64, 9, padding='same', activation='relu')(x)
x = tf.concat([x, skip_1], -1)
skip_2 = layers.MaxPool2D()(x)

x = layers.Conv2D(128, 9, padding='same', activation='relu')(skip_2)
x = layers.Conv2D(128, 9, padding='same', activation='relu')(x)
x = layers.Conv2D(128, 9, padding='same', activation='relu')(x)
x = tf.concat([x, skip_2], -1)
skip_3 = layers.MaxPool2D()(x)

x = layers.Conv2D(256, 9, padding='same', activation='relu')(skip_3)
x = layers.Conv2D(256, 9, padding='same', activation='relu')(x)
x = layers.Conv2D(256, 9, padding='same', activation='relu')(x)
x = tf.concat([x, skip_3], -1)
x = layers.MaxPool2D()(x)
x = layers.Dropout(0.3)(x)

x = layers.Flatten()(x)
x = layers.Dense(256)(x)
x = layers.BatchNormalization()(x)
x = layers.Activation('relu')(x)

output_tensor = layers.Dense(12)(x)

model_wav_skip = tf.keras.Model(input_tensor, output_tensor)

model_wav_skip.summary()


optimizer=tf.keras.optimizers.Adam(1e-4)
model_wav_skip.compile(loss=tf.keras.losses.CategoricalCrossentropy(from_logits=True),
             optimizer=optimizer,
             metrics=['accuracy'])

#callback 
cp_callback = tf.keras.callbacks.ModelCheckpoint(checkpoint_dir,
                                                 save_weights_only=True,
                                                 monitor='val_loss',
                                                 mode='auto',
                                                 save_best_only=True,
                                                 verbose=1)




#30분 내외 소요 (메모리 사용량에 주의해 주세요.)
history_wav_skip = model_wav_skip.fit(train_dataset, epochs=max_epochs,
                    steps_per_epoch=len(train_wav) // batch_size,
                    validation_data=test_dataset,
                    validation_steps=len(test_wav) // batch_size,
                    callbacks=[cp_callback]
                    )



acc = history_wav_skip.history['accuracy']
val_acc = history_wav_skip.history['val_accuracy']

loss=history_wav_skip.history['loss']
val_loss=history_wav_skip.history['val_loss']

epochs_range = range(len(acc))

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()



#evaluation
model_wav_skip.load_weights(checkpoint_dir)
results = model_wav_skip.evaluate(test_dataset)
# loss
print("loss value: {:.3f}".format(results[0]))
# accuracy
print("accuracy value: {:.4f}%".format(results[1]*100))
# Out:
# LABEL :  ['yes', 'no', 'up', 'down', 'left', 'right', 'on', 'off', 'stop', 'go', 'unknown', 'silence']
# Indexed LABEL :  {'yes': 0, 'no': 1, 'up': 2, 'down': 3, 'left': 4, 'right': 5, 'on': 6, 'off': 7, 'stop': 8, 'go': 9, 'unknown': 10, 'silence': 11}
# asdasdasd  (45558, 130, 126, 1)
# train data :  (45558, 130, 126, 1)
# train labels :  (45558,)
# test data :  (5062, 130, 126, 1)
# test labels :  (5062,)
# <BatchDataset shapes: ((None, 130, 126, 1), (None, 12)), types: (tf.float32, tf.float32)>
# <BatchDataset shapes: ((None, 130, 126, 1), (None, 12)), types: (tf.float32, tf.float32)>
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 130, 126, 1) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 130, 126, 32) 2624        input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 130, 126, 32) 82976       conv2d[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 65, 63, 32)   0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 65, 63, 64)   165952      max_pooling2d[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 65, 63, 64)   331840      conv2d_2[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_concat (TensorFlowO [(None, 65, 63, 96)] 0           conv2d_3[0][0]
#                                                                  max_pooling2d[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 32, 31, 96)   0           tf_op_layer_concat[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 32, 31, 128)  995456      max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 32, 31, 128)  1327232     conv2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 32, 31, 128)  1327232     conv2d_5[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_concat_1 (TensorFlo [(None, 32, 31, 224) 0           conv2d_6[0][0]
#                                                                  max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 16, 15, 224)  0           tf_op_layer_concat_1[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 16, 15, 256)  4645120     max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 16, 15, 256)  5308672     conv2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 16, 15, 256)  5308672     conv2d_8[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_concat_2 (TensorFlo [(None, 16, 15, 480) 0           conv2d_9[0][0]
#                                                                  max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 8, 7, 480)    0           tf_op_layer_concat_2[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 8, 7, 480)    0           max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 26880)        0           dropout[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 256)          6881536     flatten[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 256)          1024        dense[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 256)          0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 12)           3084        activation[0][0]
# ==================================================================================================
# Total params: 26,381,420
# Trainable params: 26,380,908
# Non-trainable params: 512
# __________________________________________________________________________________________________
# Epoch 1/10
# 2847/2847 [==============================] - ETA: 0s - loss: 0.6703 - accuracy: 0.7843
# Epoch 00001: val_loss improved from inf to 0.28964, saving model to /home/ssac16/aiffel/speech_recognition/models/spectrogram_skip
# 2847/2847 [==============================] - 321s 113ms/step - loss: 0.6703 - accuracy: 0.7843 - val_loss: 0.2896 - val_accuracy: 0.9138
# Epoch 2/10
# 2847/2847 [==============================] - ETA: 0s - loss: 0.2131 - accuracy: 0.9341
# Epoch 00002: val_loss improved from 0.28964 to 0.21920, saving model to /home/ssac16/aiffel/speech_recognition/models/spectrogram_skip
# 2847/2847 [==============================] - 327s 115ms/step - loss: 0.2131 - accuracy: 0.9341 - val_loss: 0.2192 - val_accuracy: 0.9343
# Epoch 3/10
# 2847/2847 [==============================] - ETA: 0s - loss: 0.1425 - accuracy: 0.9556
# Epoch 00003: val_loss improved from 0.21920 to 0.15759, saving model to /home/ssac16/aiffel/speech_recognition/models/spectrogram_skip
# 2847/2847 [==============================] - 322s 113ms/step - loss: 0.1425 - accuracy: 0.9556 - val_loss: 0.1576 - val_accuracy: 0.9464
# Epoch 4/10
# 2847/2847 [==============================] - ETA: 0s - loss: 0.1087 - accuracy: 0.9651
# Epoch 00004: val_loss improved from 0.15759 to 0.12484, saving model to /home/ssac16/aiffel/speech_recognition/models/spectrogram_skip
# 2847/2847 [==============================] - 332s 117ms/step - loss: 0.1087 - accuracy: 0.9651 - val_loss: 0.1248 - val_accuracy: 0.9591
# Epoch 5/10
# 2847/2847 [==============================] - ETA: 0s - loss: 0.0857 - accuracy: 0.9722
# Epoch 00005: val_loss did not improve from 0.12484
# 2847/2847 [==============================] - 334s 117ms/step - loss: 0.0857 - accuracy: 0.9722 - val_loss: 0.1623 - val_accuracy: 0.9498
# Epoch 6/10
# 2847/2847 [==============================] - ETA: 0s - loss: 0.0753 - accuracy: 0.9758
# Epoch 00006: val_loss did not improve from 0.12484
# 2847/2847 [==============================] - 339s 119ms/step - loss: 0.0753 - accuracy: 0.9758 - val_loss: 0.1322 - val_accuracy: 0.9610
# Epoch 7/10
# 2847/2847 [==============================] - ETA: 0s - loss: 0.0639 - accuracy: 0.9791
# Epoch 00007: val_loss improved from 0.12484 to 0.12107, saving model to /home/ssac16/aiffel/speech_recognition/models/spectrogram_skip
# 2847/2847 [==============================] - 347s 122ms/step - loss: 0.0639 - accuracy: 0.9791 - val_loss: 0.1211 - val_accuracy: 0.9640
# Epoch 8/10
# 2847/2847 [==============================] - ETA: 0s - loss: 0.0571 - accuracy: 0.9812
# Epoch 00008: val_loss did not improve from 0.12107
# 2847/2847 [==============================] - 355s 125ms/step - loss: 0.0571 - accuracy: 0.9812 - val_loss: 0.1508 - val_accuracy: 0.9579
# Epoch 9/10
# 2847/2847 [==============================] - ETA: 0s - loss: 0.0524 - accuracy: 0.9829
# Epoch 00009: val_loss improved from 0.12107 to 0.11591, saving model to /home/ssac16/aiffel/speech_recognition/models/spectrogram_skip
# 2847/2847 [==============================] - 327s 115ms/step - loss: 0.0524 - accuracy: 0.9829 - val_loss: 0.1159 - val_accuracy: 0.9656
# Epoch 10/10
# 2847/2847 [==============================] - ETA: 0s - loss: 0.0469 - accuracy: 0.9845
# Epoch 00010: val_loss did not improve from 0.11591
# 2847/2847 [==============================] - 320s 112ms/step - loss: 0.0469 - accuracy: 0.9845 - val_loss: 0.1163 - val_accuracy: 0.9648
# 317/317 [==============================] - 31s 98ms/step - loss: 0.1158 - accuracy: 0.9656
# loss value: 0.116
# accuracy value: 96.5626%
